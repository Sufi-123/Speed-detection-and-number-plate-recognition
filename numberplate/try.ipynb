# %%
import cv2
import easyocr
from IPython.display import Image, display

import ultralytics
ultralytics.checks()
from ultralytics import YOLO
# Out:
# Ultralytics YOLOv8.0.117 🚀 Python-3.9.13 torch-2.0.1+cu117 CPU
# Setup complete ✅ (4 CPUs, 3.7 GB RAM, 77.7/233.2 GB disk)

# %%
# Load a pretrained model
model = YOLO('best.pt') 
model.conf = 0.4  # Confidence threshold for detection

# %%
# Initializing OCR
reader = easyocr.Reader(['en', 'ne'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
def recognize_number_plate(video_path):
    # Open the video file
    video = cv2.VideoCapture(video_path)
    
    # Initialize an empty list to store recognized number plates
    recognized_plates = []
    
    # Read frames from the video
    while True:
        ret, frame = video.read()
        
        # Check if a frame was successfully read
        if not ret:
            break
        
        # Perform object detection using YOLO
        detections = model(frame)
        
        # Extract bounding boxes and crop number plate regions
        number_plate_box = None
        for detection in detections[0].boxes.data:
            if detection[5] == 0:  
                number_plate_box = detection[:4]
                break
        
        # Crop the number plate region
        if number_plate_box is not None:
            x1, y1, x2, y2 = number_plate_box
            cropped_image = frame[int(y1):int(y2), int(x1):int(x2)]
            
            # # Display the cropped image
            # display(Image(data=cv2.imencode('.jpg', cropped_image)[1].tobytes()))
            
            # Perform OCR on the number plate image
            result = reader.readtext(cropped_image, allowlist='0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ ', detail=0)
            
            # Extract the text from the OCR result
            recognized_plate = ''.join(result)
            
            # Add the recognized plate to the list
            recognized_plates.append(recognized_plate)
    
    # Release the video file
    video.release()
    
    return recognized_plates

# %%
# Path to video file
video_path = '123.mp4'  
recognized_plates = recognize_number_plate(video_path)
# Out:
# 0: 480x800 (no detections), 382.7ms
# Speed: 8.3ms preprocess, 382.7ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 (no detections), 387.1ms
# Speed: 6.1ms preprocess, 387.1ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 (no detections), 396.0ms
# Speed: 6.1ms preprocess, 396.0ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 (no detections), 374.2ms
# Speed: 6.7ms preprocess, 374.2ms inference, 0.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 378.5ms
# Speed: 6.8ms preprocess, 378.5ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 366.1ms
# Speed: 6.3ms preprocess, 366.1ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 373.6ms
# Speed: 6.3ms preprocess, 373.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 381.9ms
# Speed: 6.4ms preprocess, 381.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 384.2ms
# Speed: 6.1ms preprocess, 384.2ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 425.9ms
# Speed: 9.7ms preprocess, 425.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 2 License-plates, 379.3ms
# Speed: 6.1ms preprocess, 379.3ms inference, 1.2ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 398.6ms
# Speed: 6.2ms preprocess, 398.6ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 671.2ms
# Speed: 6.4ms preprocess, 671.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 439.4ms
# Speed: 7.3ms preprocess, 439.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 402.5ms
# Speed: 5.8ms preprocess, 402.5ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 389.5ms
# Speed: 5.8ms preprocess, 389.5ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 375.7ms
# Speed: 5.9ms preprocess, 375.7ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 373.4ms
# Speed: 5.8ms preprocess, 373.4ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 449.5ms
# Speed: 9.1ms preprocess, 449.5ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 398.2ms
# Speed: 6.0ms preprocess, 398.2ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 367.3ms
# Speed: 6.3ms preprocess, 367.3ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 365.5ms
# Speed: 6.3ms preprocess, 365.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 373.0ms
# Speed: 6.1ms preprocess, 373.0ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate,
2ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 413.0ms
# Speed: 5.5ms preprocess, 413.0ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 367.0ms
# Speed: 6.2ms preprocess, 367.0ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
# 0: 480x800 1 License-plate, 406.9ms
# Speed: 6.4ms preprocess, 406.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 368.4ms
# Speed: 6.6ms preprocess, 368.4ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 364.5ms
# Speed: 5.3ms preprocess, 364.5ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 691.2ms
# Speed: 8.2ms preprocess, 691.2ms inference, 2.7ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 394.5ms
# Speed: 5.6ms preprocess, 394.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 401.6ms
# Speed: 6.5ms preprocess, 401.6ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 367.9ms
# Speed: 5.8ms preprocess, 367.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 393.1ms
# Speed: 5.5ms preprocess, 393.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 370.2ms
# Speed: 5.0ms preprocess, 370.2ms inference, 1.4ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 354.5ms
# Speed: 6.0ms preprocess, 354.5ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 364.4ms
# Speed: 7.5ms preprocess, 364.4ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 354.4ms
# Speed: 5.7ms preprocess, 354.4ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 355.7ms
# Speed: 6.0ms preprocess, 355.7ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 356.7ms
# Speed: 6.4ms preprocess, 356.7ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 358.1ms
# Speed: 5.4ms preprocess, 358.1ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 355.7ms
# Speed: 5.8ms preprocess, 355.7ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 354.9ms
# Speed: 5.5ms preprocess, 354.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 356.4ms
# Speed: 5.8ms preprocess, 356.4ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 357.4ms
# Speed: 5.6ms preprocess, 357.4ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 356.3ms
# Speed: 5.4ms preprocess, 356.3ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 359.0ms
# Speed: 5.4ms preprocess, 359.0ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 357.3ms
# Speed: 6.0ms preprocess, 357.3ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 356.9ms
# Speed: 5.9ms preprocess, 356.9ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 358.0ms
# Speed: 5.7ms preprocess, 358.0ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 357.0ms
# Speed: 6.0ms preprocess, 357.0ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 376.2ms
# Speed: 5.6ms preprocess, 376.2ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 357.2ms
# Speed: 5.2ms preprocess, 357.2ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 358.3ms
# Speed: 5.5ms preprocess, 358.3ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 356.2ms
# Speed: 5.3ms preprocess, 356.2ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 355.0ms
# Speed: 5.8ms preprocess, 355.0ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 357.6ms
# Speed: 5.6ms preprocess, 357.6ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 357.2ms
# Speed: 5.2ms preprocess, 357.2ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 357.4ms
# Speed: 5.7ms preprocess, 357.4ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 356.8ms
# Speed: 5.3ms preprocess, 356.8ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 356.0ms
# Speed: 5.4ms preprocess, 356.0ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 480x800 1 License-plate, 354.1ms
# Speed: 5.1ms preprocess, 354.1ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 800)

# %%
# # # Print the recognized number plates
# for plate in recognized_plates:
#     print(plate)
# Out:
# UL3 F4
#
#
#
# IL3
#
# 0Y0TFO
#
# IY0 7
# 0V0 7
#
#
# 0Y01 R00
# 0403 700
# 0N03 R00
# 0V03 R00
# DV3 R0D
# UV03 R00
# W03 P0 0
# OVODIPOU
# 0M03 900
# V0 3 P00
# 0M0 3 900
# O07 P0L
# O07 201
# ONOJ POJ
# O403 200
# 0V03 200
# LOVOD P7D
# OVDJ POU
# IOVOJ FO
# OV03 FOU
# OVO3 POU
# OV03 P0U
# OV0J FOU
# OVO J PO
# OVOJ POJ
# OVO J POJ
# OVOJ POJ
# IVO3 RO
# IOVO3 POJ
# OY03 POUI
# OY03 POJ
# OYO3 POJ
# OVO3 POU
# OVO3 POU
# 0V03 POJ
# 0VO3 PO J
# OVO3 PO
# OVO3 PO J
# OVO3 PO J
# 0VO3 PD J
# 0403P00
# 003 R00
# I0L030J
# OY03 P0U
# OVO3 P0 J
# OVO3 POJ
# 0V03IP0J
# OV03 P0D
# 0V03IP00
# 0V03 P00
# 0V03 P0U
# 0V03 P00
# OVO3 POJ
# OVOJ POJ
# OYO3 POJ
# LOVO3 POJ
# LOVO3 POJ
# OYO3IP0 J
# OYO3IPO D
# OYO3 PO D
# OYO3 PO J
# OVOD PO J
# OV03 POJ
# VO3IPOD
# OVO3IPO J
# OVO3 POJI
# OVO3 PO J
# OVO3 POJ
# OVO3 PO
# OVO3IPOJ
# OVO3IPOJ
# OVO3IPOJ
# OVO3IPOD
# OVO3IPO
# OVO3IPOJ
# OYO3
# 0V03
# 0V03
# 0V03
# 0VO3 PO
# 0Y03P0
# 0Y03 P0
# 0V03
# 0Y03
# OVO3 P0
# OYO3IP0
# OYOJPU
# OYO J
# OY0
# OY0
#
#
#
# OVU
# OYO
# OVO FU
# OYO F
# OVOJY
# OYU J
# OYO J
# OYOJ P
# OYO3
# OYO3
# OVOJ P
# OYOJ PU
# OVO 3
# OVOJRO
# OVOः
# OYO5
# OY03
# OYO3
# OYO3
# OY03
# 0Y03
# 0V03
# 0V03
# 0V03
# 0V03
# 0V03
# 0V03
# OVD3
# OVD3 PUJ
# OVD3
# OVO3 PUJ
# OVO3 POJ
# OVO3 POJ
# OVO3 PO J
# OVO3 PO J
# OVO3 POJ
# OVO3 POJ
# OVO3 PO J
# OYO3PO J
# OYO3 PO J
# OYO3 PO J
# OVO3 POJ
# OVO3 PO J
# OVO3 POJ
# 0V03 P0J
# OVO3 POJ
# OVO3 POJ
# OVO3 POJ
# OVO3 POJ
# OVO3 POJ
# OVO3IPOJ
# OYO3 POJ
# OYO3 POJ
# OYO3 POJ
# OYO3 POJ
# OYO3 POJ
# OVO3IPO J
# OVO3IP0 J
# OVO3IPO J
# OVO3IPO J
# OVO3IPO J
# OYO3 POJ
# OYO3 POJ
# OYO3 POJ
# OYO3 POJ
# OVO3 PO J
# OVO3 PO J
# OYO3 PO J
# OYO3IPO J
# OVO3 IPO J
# OVO3 PO J
# OVO3 PO J
# OVO3 IPO J
# OVO3 POJ
# OVO3 POJ
# OVO3 POJ
# OVO3 POJ
# OVO3 POJ
# OVO3 POJ
# 0VO3IPO J
# OVO3IPO J
# OYO3IPOJ
# OYO3IPO J
# OYO3IPO J
# OYO3 PO J
# OYO3 POJ
# 0Y03 PO J
# OYO3 POJ
# OYO3 POJ
# OYO3 POJ
# OY03 POJ
# OY03 P0J
# OVD3 POJ
# OYD3IPOJ
# OVO3IPOJ
# OVO3 POJ
# OVO3 POJ
# OVO3 POJ
# OVO3 PO J
# OVO3 POJ

# %%
print(recognized_plates)
# Out:
# None
